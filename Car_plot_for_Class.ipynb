# %%
import numpy as np

import pandas as pd

# %%
import os

os.getcwd()
# Out:
# 'C:\\Users\\HP\\My Python'

# %%
os.chdir("D:\\")

# %%
car_price = pd.read_csv("C:\\Users\\HP\\Downloads\\UpGrad\\carprices_data_viz.csv")

# %%
car_price
# Out:
#      car_ID  symboling                   carname doornumber      carbody  \
# 0       1.0        3.0        alfa-romero giulia        two  convertible
# 1       2.0        3.0       alfa-romero stelvio        two  convertible
# 2       3.0        1.0  alfa-romero Quadrifoglio        two    hatchback
# 3       4.0        2.0               audi 100 ls       four        sedan
# 4       5.0        2.0                audi 100ls       four        sedan
# ..      ...        ...                       ...        ...          ...
# 200   201.0       -1.0           volvo 145e (sw)       four        sedan
# 201   202.0       -1.0               volvo 144ea       four        sedan
# 202   203.0       -1.0               volvo 244dl       four        sedan
# 203   204.0       -1.0                 volvo 246       four        sedan
# 204   205.0       -1.0               volvo 264gl       four        sedan
#
#     enginelocation  wheelbase  carlength  carwidth  carheight  ...  \
# ...

# %%
car_price.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            204 non-null    float64
#  1   symboling         204 non-null    float64
#  2   carname           205 non-null    object
#  3   doornumber        196 non-null    object
#  4   carbody           205 non-null    object
#  5   enginelocation    204 non-null    object
#  6   wheelbase         191 non-null    float64
#  7   carlength         204 non-null    float64
#  8   carwidth          204 non-null    float64
#  9   carheight         204 non-null    float64
#  10  curbweight        205 non-null    int64
#  11  cylindernumber    204 non-null    object
#  12  enginesize        204 non-null    float64
#  13  boreratio         205 non-null    float64
#  14  stroke            204 non-null    float64
#  15  compressionratio  204 non-null    float64
# ...

# %%
car_price.isnull().sum()
# Out:
# car_ID               1
# symboling            1
# carname              0
# doornumber           9
# carbody              0
# enginelocation       1
# wheelbase           14
# carlength            1
# carwidth             1
# carheight            1
# curbweight           0
# cylindernumber       1
# enginesize           1
# boreratio            0
# stroke               1
# compressionratio     1
# horsepower           1
# peakrpm              0
# citympg              0
# highwaympg           1
# price                1
# dtype: int64

# %%
car_price.loc[car_price['car_ID'].isna(),:]
# Out:
#     car_ID  symboling            carname doornumber    carbody enginelocation  \
# 24     NaN        NaN  dodge monaco (sw)        NaN  hatchback            NaN
#
#     wheelbase  carlength  carwidth  carheight  ...  cylindernumber enginesize  \
# 24       93.7        NaN       NaN        NaN  ...             NaN        NaN
#
#     boreratio  stroke  compressionratio  horsepower  peakrpm  citympg  \
# 24       2.97     NaN               NaN         NaN     5500       31
#
#     highwaympg  price
# 24         NaN    NaN
#
# [1 rows x 21 columns]

# %%
car_price.loc[car_price['car_ID'].isnull(),:]
# Out:
#     car_ID  symboling            carname doornumber    carbody enginelocation  \
# 24     NaN        NaN  dodge monaco (sw)        NaN  hatchback            NaN
#
#     wheelbase  carlength  carwidth  carheight  ...  cylindernumber enginesize  \
# 24       93.7        NaN       NaN        NaN  ...             NaN        NaN
#
#     boreratio  stroke  compressionratio  horsepower  peakrpm  citympg  \
# 24       2.97     NaN               NaN         NaN     5500       31
#
#     highwaympg  price
# 24         NaN    NaN
#
# [1 rows x 21 columns]

# %%
car_price.shape
# Out:
# (205, 21)

# %%
car_price.size
# Out:
# 4305

# %%
car_price.loc[car_price['car_ID'].isnull(),['carname']]
# Out:
#               carname
# 24  dodge monaco (sw)

# %% [markdown]
# you can also check the name of the car & see to it if that helps

# %%
car_price.drop(24, inplace = True, axis = 0) #axis = 0 mean remove raws & axis = 1 mean remove column

# %%
car_price.shape
# Out:
# (204, 21)

# %%
car_price.isnull().sum()
# Out:
# car_ID               0
# symboling            0
# carname              0
# doornumber           8
# carbody              0
# enginelocation       0
# wheelbase           14
# carlength            0
# carwidth             0
# carheight            0
# curbweight           0
# cylindernumber       0
# enginesize           0
# boreratio            0
# stroke               0
# compressionratio     0
# horsepower           0
# peakrpm              0
# citympg              0
# highwaympg           0
# price                0
# dtype: int64

# %%
car_price
# Out:
#      car_ID  symboling                   carname doornumber      carbody  \
# 0       1.0        3.0        alfa-romero giulia        two  convertible
# 1       2.0        3.0       alfa-romero stelvio        two  convertible
# 2       3.0        1.0  alfa-romero Quadrifoglio        two    hatchback
# 3       4.0        2.0               audi 100 ls       four        sedan
# 4       5.0        2.0                audi 100ls       four        sedan
# ..      ...        ...                       ...        ...          ...
# 200   201.0       -1.0           volvo 145e (sw)       four        sedan
# 201   202.0       -1.0               volvo 144ea       four        sedan
# 202   203.0       -1.0               volvo 244dl       four        sedan
# 203   204.0       -1.0                 volvo 246       four        sedan
# 204   205.0       -1.0               volvo 264gl       four        sedan
#
#     enginelocation  wheelbase  carlength  carwidth  carheight  ...  \
# ...

# %%
car_price['wheelbase'].isnull().sum()
# Out:
# np.int64(14)

# %%
car_price.loc[car_price['wheelbase'].isnull(),:]
# Out:
#      car_ID  symboling                    carname doornumber    carbody  \
# 6       7.0        1.0                 audi 100ls       four      sedan
# 12     13.0        0.0                     bmw x1        two      sedan
# 29     30.0        3.0  dodge coronet custom (sw)        two  hatchback
# 30     31.0        2.0                honda civic        two  hatchback
# 32     33.0        1.0                honda civic        two  hatchback
# 53     54.0        1.0                 mazda rx-4       four      sedan
# 63     64.0        0.0           mazda glc deluxe       four      sedan
# 76     77.0        2.0          mitsubishi mirage        two  hatchback
# 102   103.0        0.0                nissan fuga       four      wagon
# 118   119.0        1.0          plymouth fury iii        two  hatchback
# 125   126.0        3.0              porsche macan        two  hatchback
# 146   147.0        0.0              subaru trezia       four      wagon
# ...

# %%
car_price.loc[car_price['wheelbase'].isna(),:]
# Out:
#      car_ID  symboling                    carname doornumber    carbody  \
# 6       7.0        1.0                 audi 100ls       four      sedan
# 12     13.0        0.0                     bmw x1        two      sedan
# 29     30.0        3.0  dodge coronet custom (sw)        two  hatchback
# 30     31.0        2.0                honda civic        two  hatchback
# 32     33.0        1.0                honda civic        two  hatchback
# 53     54.0        1.0                 mazda rx-4       four      sedan
# 63     64.0        0.0           mazda glc deluxe       four      sedan
# 76     77.0        2.0          mitsubishi mirage        two  hatchback
# 102   103.0        0.0                nissan fuga       four      wagon
# 118   119.0        1.0          plymouth fury iii        two  hatchback
# 125   126.0        3.0              porsche macan        two  hatchback
# 146   147.0        0.0              subaru trezia       four      wagon
# ...

# %%
car_price['wheelbase'].median()
# Out:
# 97.0

# %%
car_price['wheelbase'].fillna(car_price['wheelbase'].median(),inplace = True)

car_price['wheelbase'].isnull().sum()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_22788\2781551472.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   car_price['wheelbase'].fillna(car_price['wheelbase'].median(),inplace = True)
# np.int64(0)

# %%
car_price.isnull().sum()
# Out:
# car_ID              0
# symboling           0
# carname             0
# doornumber          8
# carbody             0
# enginelocation      0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# cylindernumber      0
# enginesize          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# dtype: int64

# %%
car_price['doornumber'].isnull().sum()
# Out:
# np.int64(8)

# %%
car_price['doornumber'].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 200    False
# 201    False
# 202    False
# 203    False
# 204    False
# Name: doornumber, Length: 204, dtype: bool

# %%
car_price.loc[car_price['doornumber'].isna(),:]
# Out:
#      car_ID  symboling                    carname doornumber    carbody  \
# 21     22.0        1.0              dodge rampage        NaN  hatchback
# 61     62.0        1.0           mazda glc custom        NaN  hatchback
# 85     86.0        1.0         mitsubishi montero        NaN      sedan
# 96     97.0        1.0               nissan latio        NaN      sedan
# 107   108.0        0.0                peugeot 504        NaN      sedan
# 108   109.0        0.0                peugeot 304        NaN      sedan
# 114   115.0        0.0  peugeot 505s turbo diesel        NaN      wagon
# 147   148.0        0.0             subaru tribeca        NaN      wagon
#
#     enginelocation  wheelbase  carlength  carwidth  carheight  ...  \
# 21           front       93.7      157.3      63.8       50.8  ...
# 61           front       98.8      177.8      66.5       53.7  ...
# 85           front       96.3      172.4      65.4       51.6  ...
# ...

# %%
k = car_price['doornumber'].mode()
k
# Out:
# 0    four
# Name: doornumber, dtype: object

# %%
type(k)
# Out:
# pandas.core.series.Series

# %%
g = list(k.values)
g[0]
# Out:
# 'four'

# %%
type(g)
# Out:
# list

# %%
car_price['doornumber'].fillna('k',inplace = True)
car_price['doornumber'].isnull().sum()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_22788\92216321.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   car_price['doornumber'].fillna('k',inplace = True)
# np.int64(0)

# %%
car_price['doornumber'].fillna(car_price['doornumber'].mode(),inplace = True)

car_price['doornumber'].isnull().sum()
# Out:
# np.int64(0)

# %%
car_price['doornumber'].fillna(g[0],inplace = True)
car_price['doornumber'].isnull().sum()
# Out:
# np.int64(0)

# %%
car_price.isnull().sum()
# Out:
# car_ID              0
# symboling           0
# carname             0
# doornumber          0
# carbody             0
# enginelocation      0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# cylindernumber      0
# enginesize          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# dtype: int64

# %%
car_price['enginelocation'].value_counts()
# Out:
# enginelocation
# front    201
# rear       3
# Name: count, dtype: int64

# %%
car_price[car_price['enginelocation'] =='rear']
# Out:
#      car_ID  symboling            carname doornumber      carbody  \
# 126   127.0        3.0  porcshce panamera        two      hardtop
# 127   128.0        3.0    porsche cayenne        two      hardtop
# 128   129.0        3.0     porsche boxter        two  convertible
#
#     enginelocation  wheelbase  carlength  carwidth  carheight  ...  \
# 126           rear       89.5      168.9      65.0       51.6  ...
# 127           rear       89.5      168.9      65.0       51.6  ...
# 128           rear       89.5      168.9      65.0       51.6  ...
#
#      cylindernumber enginesize  boreratio  stroke  compressionratio  \
# 126             six      194.0       3.74     2.9               9.5
# 127             six      194.0       3.74     2.9               9.5
# 128             six      194.0       3.74     2.9               9.5
#
#      horsepower  peakrpm  citympg  highwaympg    price
# 126       207.0     5900       17        25.0  32528.0
# ...

# %%
import os

os.getcwd()
# Out:
# 'D:\\'

# %%
os.chdir("D:\\")

# %%
car_price.to_csv("clean_carprices_df.csv",index = False)

# %%
import os

os.getcwd()
# Out:
# 'D:\\'

# %%
os.chdir("D:\\")

# %%
car_clean_price = pd.read_csv('clean_carprices_df.csv')


car_clean_price
# Out:
#      car_ID  symboling                   carname doornumber      carbody  \
# 0       1.0        3.0        alfa-romero giulia        two  convertible
# 1       2.0        3.0       alfa-romero stelvio        two  convertible
# 2       3.0        1.0  alfa-romero Quadrifoglio        two    hatchback
# 3       4.0        2.0               audi 100 ls       four        sedan
# 4       5.0        2.0                audi 100ls       four        sedan
# ..      ...        ...                       ...        ...          ...
# 199   201.0       -1.0           volvo 145e (sw)       four        sedan
# 200   202.0       -1.0               volvo 144ea       four        sedan
# 201   203.0       -1.0               volvo 244dl       four        sedan
# 202   204.0       -1.0                 volvo 246       four        sedan
# 203   205.0       -1.0               volvo 264gl       four        sedan
#
#     enginelocation  wheelbase  carlength  carwidth  carheight  ...  \
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(x = car_clean_price['enginesize'], y = car_clean_price['horsepower'], s =10 # s = size of the text
           )
plt.title('Engine vs H.P. Scatter Plot')
plt.xlabel('Engine Volume in CC')   # cc = cubic centimeter
plt.ylabel('Horse Power')
#plt.colorbar('Engine Volume in CC')
plt.show()

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# num vs num - Scatter plot

# %% [markdown]
# cb = plt.colorbar(plt.cm.ScalarMappable(norm=norm, cmap=cmap))
# cb.set_label('Color Scale')

# %%
plt.scatter(x = car_clean_price['enginesize'], y = car_clean_price['citympg'] ,s =10)
plt.title('Engine vs Mileage Scatter Plot')
plt.xlabel('Engine Volume in CC')
plt.ylabel('citympg')
#plt.colorbar('Engine Volume in CC')
plt.show()

# %%
plt.scatter( x = car_clean_price['horsepower'], y = car_clean_price['citympg'],s=10, c= 'purple' , marker = '*')
plt.title('horsepower vs Mileage Sactter Plot')
plt.xlabel('Horsepower')
plt.ylable('citympg')
#plt.colorbar('Engine Volume in CC')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[50], line 4
#       2 plt.title('horsepower vs Mileage Sactter Plot')
#       3 plt.xlabel('Horsepower')
# ----> 4 plt.ylable('citympg')
#       5 #plt.colorbar('Engine Volume in CC')
#       6 plt.show()
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'ylable'

# %%
plt.scatter(x = car_clean_price['horsepower'], y = car_clean_price['citympg'] ,s =10, c ="red", marker = '^')
plt.title('horsepower vs Mileage Scatter Plot')
plt.xlabel('Horsepower')
plt.ylabel('citympg')
#plt.colorbar('Engine Volume in CC')
plt.show()

# %%
doornumber_value_counts = car_clean_price['doornumber'].value_counts()

doornumber_value_counts
# Out:
# doornumber
# four    108
# two      88
# k         8
# Name: count, dtype: int64

# %%
plt.pie(x = doornumber_value_counts.values , labels = doornumber_value_counts.index , colors = ['yellow', 'blue' , 'green'])
plt.title("Doornumber 2 or 4 - Pie Chart")
plt.show()

# %%
plt.pie(x = doornumber_value_counts.values, labels = doornumber_value_counts.index, colors =['yellow', 'blue'])
plt.title("Doornumber  2 or 4 - Pie Chart")
plt.show()

# %% [markdown]
# num vs categorical

# %% [markdown]
# categorical vs num

# %%
plt.scatter(x = car_clean_price['carbody'], y = car_clean_price['citympg'] ,s =10, c ="red", marker = '^')


plt.ylabel('horsepower')
#plt.colorbar('Engine Volume in CC')
plt.show()

# %%
carbody_value_counts = car_clean_price['carbody'].value_counts()



carbody_value_counts
# Out:
# carbody
# sedan          96
# hatchback      69
# wagon          25
# hardtop         8
# convertible     6
# Name: count, dtype: int64

# %%
plt.pie( x = carbody_value_counts.values, labels =carbody_value_counts.index)



plt.show()

# %% [markdown]
# tag_names =[]
#
# for a in zip (carbody_value_counts.index, carbody_value_counts.values

# %%
plt.bar(x = carbody_value_counts.index , height = carbody_value_counts.values , color = 'pink')
plt.title('Carbody vs numbers')
plt.xlable('Carbody Type')
plt.ylable('Number of car')

#plt.colorbar("Engine Volume in CC')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[58], line 3
#       1 plt.bar(x = carbody_value_counts.index , height = carbody_value_counts.values , color = 'pink')
#       2 plt.title('Carbody vs numbers')
# ----> 3 plt.xlable('Carbody Type')
#       4 plt.ylable('Number of car')
#       6 #plt.colorbar("Engine Volume in CC')
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'xlable'

# %%
plt.bar(x = carbody_value_counts.index, height = carbody_value_counts.values, color ='lightgreen' )
plt.title('Carbody vs numbers')
plt.xlabel('Carbody Type')
plt.ylabel('Number of cars')



#plt.colorbar('Engine Volume in CC')
plt.show()

# %%
avg_prices = car_clean_price.groupby('carbody')['price'].mean()
avg_prices
avg_prices.sort_values(ascending = False, inplace =True)

avg_prices
# Out:
# carbody
# hardtop        22208.500000
# convertible    21890.500000
# sedan          14344.270833
# wagon          12371.960000
# hatchback      10436.763290
# Name: price, dtype: float64

# %%
plt.pie(labels =avg_prices.index, x =avg_prices.values)

plt.show()

# %%
plt.bar(x = avg_prices.index, height = avg_prices.values, color ='purple' )
plt.title('Carbody vs numbers')
plt.xlabel('Carbody Type')
plt.ylabel('price of cars')



#plt.colorbar('Engine Volume in CC')
plt.show()

# %%
plt.barh(y = avg_prices.index, width = avg_prices.values, color ='purple' )
#plt.title('Carbody vs numbers')
#plt.xlabel('Carbody Type')
#plt.ylabel('Number of cars')



#plt.colorbar('Engine Volume in CC')
plt.show()

# %%
car_clean_price
# Out:
#      car_ID  symboling                   carname doornumber      carbody  \
# 0       1.0        3.0        alfa-romero giulia        two  convertible
# 1       2.0        3.0       alfa-romero stelvio        two  convertible
# 2       3.0        1.0  alfa-romero Quadrifoglio        two    hatchback
# 3       4.0        2.0               audi 100 ls       four        sedan
# 4       5.0        2.0                audi 100ls       four        sedan
# ..      ...        ...                       ...        ...          ...
# 199   201.0       -1.0           volvo 145e (sw)       four        sedan
# 200   202.0       -1.0               volvo 144ea       four        sedan
# 201   203.0       -1.0               volvo 244dl       four        sedan
# 202   204.0       -1.0                 volvo 246       four        sedan
# 203   205.0       -1.0               volvo 264gl       four        sedan
#
#     enginelocation  wheelbase  carlength  carwidth  carheight  ...  \
# ...

# %%
import seaborn as sns

# %%
sns.scatterplot(x = car_clean_price['carbody'], y = car_clean_price['horsepower'] ,s =10, c ="red", marker = '^')


plt.ylabel('horsepower')
#plt.colorbar('Engine Volume in CC')
plt.show()

# %%
sns.scatterplot(x = car_clean_price['carbody'], y = car_clean_price['citympg'] ,s =10, c ="red", marker = '^')


plt.ylabel('citympg')
#plt.colorbar('Engine Volume in CC')
plt.show()

# %%
plt.figure(figsize=[14,4])
sns.scatterplot(x = car_clean_price['enginesize'], y = car_clean_price['citympg'] ,s =10)
#sns.title('Engine vs Mileage Scatter Plot')
#sns.xlabel('Engine Volume in CC')
#sns.ylabel('citympg')
#plt.colorbar('Engine Volume in CC')
plt.show()

# %%
plt.figure(figsize=[14,4])
sns.scatterplot(x = car_clean_price['enginesize'], 
                y = car_clean_price['price'] ,
                 style = car_clean_price['doornumber'],
                  hue = car_clean_price['citympg'],
                   size = car_clean_price['curbweight'])

plt.show()

# %%
help(sns.scatterplot)
# Out:
# Help on function scatterplot in module seaborn.relational:
#
# scatterplot(
#     data=None,
#     *,
#     x=None,
#     y=None,
#     hue=None,
#     size=None,
#     style=None,
#     palette=None,
#     hue_order=None,
#     hue_norm=None,
#     sizes=None,
#     size_order=None,
#     size_norm=None,
#     markers=True,
#     style_order=None,
#     legend='auto',
#     ax=None,
#     **kwargs
# )
#     Draw a scatter plot with possibility of several semantic groupings.
#
#     The relationship between `x` and `y` can be shown for different subsets
#     of the data using the `hue`, `size`, and `style` parameters. These
#     parameters control what visual semantics are used to identify the different
#     subsets. It is possible to show up to three dimensions independently by
#     using all three semantic types, but this style of plot can be hard to
#     interpret and is often ineffective. Using redundant semantics (i.e. both
# ...

# %%
plt.figure(figsize=[5,3])
sns.barplot(x = car_clean_price['carbody'], 
                y = car_clean_price['price'] ,estimator =np.median
                 )

plt.show()

# %%
plt.figure(figsize=[8,3])
sns.barplot(x = car_clean_price['carbody'], 
                y = car_clean_price['price'] ,estimator =np.median
                 )

plt.xticks(rotation=45)

plt.show()

# %%
plt.figure(figsize=[8,3])
sns.barplot(x = car_clean_price['carbody'], 
                y = car_clean_price['price'] ,estimator =np.median
                 )

plt.xticks(rotation=90)

plt.show()

# %%
plt.figure(figsize=[8,3])
sns.barplot(x = car_clean_price['carbody'], 
                y = car_clean_price['price'] ,estimator =np.mean
                 )

plt.xticks(rotation=45)

plt.show()

# %%
plt.subplot(221)
 ax1= 
plt.subplot(2,2,1)
ax2 = plt.subplot(223, frameon = False)

# %%
plt.figure(figsize=[14,8])

plt.subplot(2,2,1)

sns.barplot(x = car_clean_price['carbody'], 
                y = car_clean_price['price'] ,estimator =np.mean , hue = car_clean_price['carbody'])

plt.title('Avg Prices')


plt.subplot(2,2, 2)
                 
sns.barplot(x = car_clean_price['carbody'], 
                y = car_clean_price['price'] ,estimator =np.median , hue = car_clean_price['carbody'])
                 

plt.title('Median Prices')

plt.subplot(2,2,3)
sns.barplot(x = car_clean_price['carbody'], 
                y = car_clean_price['wheelbase'] ,estimator =np.mean , hue = car_clean_price['carbody'])

plt.title('Avg wheelbase')


plt.subplot(2,2,4)
sns.barplot(x = car_clean_price['carbody'], 
                y = car_clean_price['wheelbase'] ,estimator =np.median, hue = car_clean_price['carbody'])
                  

plt.title('Median wheelbase')

plt.tight_layout()

plt.show()

# %%
plt.figure(figsize=[14,4])

plt.subplot(1,2,1)

sns.barplot(x = car_clean_price['carbody'], 
                y = car_clean_price['price'] ,estimator =np.mean)

plt.title('Avg Prices')


plt.subplot(1,2, 2)
                 
sns.barplot(x = car_clean_price['carbody'], 
                y = car_clean_price['price'] ,estimator =np.median
                 )

plt.title('Median Prices')

plt.tight_layout()

plt.show()

# %%
plt.figure(figsize=[14,4])
sns.barplot(x = car_clean_price['carbody'], 
                y = car_clean_price['price'] ,estimator =np.median,
                 #hue = car_clean_price['cylindernumber'],
            size = car_clean_price['cylindernumber'],
           dodge = False)

plt.title('Median Prices')

# %%
months = np.array(['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December'])
sales = np.array([241268.56, 184837.36, 263100.77, 242771.86, 288401.05, 401814.06, 258705.68, 456619.94, 481157.24, 422766.63, 555279.03, 503143.69])

# %%
plt.figure(figsize=[14,6])
sns.lineplot(x = months, 
                y = sales , color = 'cyan'
                 )

plt.show()

# %%
pd.set_option('display.max_columns',None)
